# %% [markdown]
# # Importando os módulos necessários:

# %%
#Importo os módulos que vou utilizar: 
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# # Pegando os dados do Yahoo Finance:

# %%
#Defino uma função que pega cotações do Yahoo Finance:
def yahoo_ticker_price(tickers):
    from pandas_datareader import data as wb
    return wb.DataReader(tickers,data_source='yahoo')['Adj Close']

# %% [markdown]
# # Estruturando os dados:

# %%
#Defino uma lista de tickers de moedas:
moedas = ['EURBRL=X','USDBRL=X','JPYBRL=X','GBPBRL=X','CADBRL=X','ARSBRL=X','INRBRL=X','CHFBRL=X','CNYBRL=X','RUBBRL=X']

#Defino um dataframe aonde vou inserir as séries de retorno de cada moeda: 
df_moedas = pd.DataFrame()

# %% [markdown]
# # Plotando as moedas duas a duas:

# %%
for i in moedas:
    for j in moedas[moedas.index(i):]:  
        if i != j:
            df_moedas[i]=yahoo_ticker_price(i).pct_change()
            ativos = pd.DataFrame()
            ativos['Ativo1']= yahoo_ticker_price(i).pct_change()
            ativos['Ativo2']= yahoo_ticker_price(j).pct_change()
            plt.scatter(ativos['Ativo1'], ativos['Ativo2'])
            plt.ylabel(j)
            plt.xlabel(i)
            plt.show()

# %% [markdown]
# # Matriz de Correlação entre as moedas:

# %%
df_moedas.corr()
# Out:
#           EURBRL=X  USDBRL=X  JPYBRL=X  GBPBRL=X  CADBRL=X  ARSBRL=X  \
# EURBRL=X  1.000000  0.840149  0.826782  0.815824  0.846445  0.533556
# USDBRL=X  0.840149  1.000000  0.900221  0.841749  0.812407  0.520778
# JPYBRL=X  0.826782  0.900221  1.000000  0.786197  0.735099  0.461627
# GBPBRL=X  0.815824  0.841749  0.786197  1.000000  0.766326  0.454363
# CADBRL=X  0.846445  0.812407  0.735099  0.766326  1.000000  0.506777
# ARSBRL=X  0.533556  0.520778  0.461627  0.454363  0.506777  1.000000
# INRBRL=X  0.362533  0.429111  0.394847  0.433638  0.332552  0.131509
# CHFBRL=X  0.934616  0.836897  0.840743  0.791678  0.871710  0.507665
# CNYBRL=X  0.369885  0.445252  0.408653  0.448812  0.349416  0.130053
#
#           INRBRL=X  CHFBRL=X  CNYBRL=X
# EURBRL=X  0.362533  0.934616  0.369885
# USDBRL=X  0.429111  0.836897  0.445252
# JPYBRL=X  0.394847  0.840743  0.408653
# GBPBRL=X  0.433638  0.791678  0.448812
# CADBRL=X  0.332552  0.871710  0.349416
# ARSBRL=X  0.131509  0.507665  0.130053
# INRBRL=X  1.000000  0.382167  0.981830
# CHFBRL=X  0.382167  1.000000  0.404876
# CNYBRL=X  0.981830  0.404876  1.000000
